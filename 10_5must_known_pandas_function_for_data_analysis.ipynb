# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
data = {'age': [25, 22, 18, 30, 45, 50, 35, 20, 55, 40],
        'gender': ['M', 'F', 'F', 'M', 'M', 'F', 'M', 'F', 'M', 'M'],
        'score': [90, 80, 75, 95, 70, 85, 75, 90, 95, 85]}
df = pd.DataFrame(data)
df
# Out:
#    age gender  score
# 0   25      M     90
# 1   22      F     80
# 2   18      F     75
# 3   30      M     95
# 4   45      M     70
# 5   50      F     85
# 6   35      M     75
# 7   20      F     90
# 8   55      M     95
# 9   40      M     85

# %%
#1. Where
df[df.where(df['age']>30,other=0).all(1)]
# Out:
#    age gender  score
# 4   45      M     70
# 5   50      F     85
# 6   35      M     75
# 8   55      M     95
# 9   40      M     85

# %%
f1 = df['age']>30
f2 = df['gender']=="M"

# %%
df[df.where(f1 & f2,other=0).all(1)]
# Out:
#    age gender  score
# 4   45      M     70
# 6   35      M     75
# 8   55      M     95
# 9   40      M     85

# %%
#2.pivot_table
df.pivot_table(index='gender',
              values='score',
              aggfunc='mean')
# Out:
#         score
# gender
# F        82.5
# M        85.0

# %%
df.pivot_table(index=['gender'],
              values=['age','score'],
              aggfunc=['sum','mean','count'])
# Out:
#         sum             mean       count
#         age score        age score   age score
# gender
# F       110   330  27.500000  82.5     4     4
# M       230   510  38.333333  85.0     6     6

# %%
#3. nlargest and nsmallest
df
df['score'].nlargest(3)
# Out:
# 3    95
# 8    95
# 0    90
# Name: score, dtype: int64

# %%
df.nlargest(3,'score')
# Out:
#    age gender  score score_bins
# 3   30      M     95  (90, 100]
# 8   55      M     95  (90, 100]
# 0   25      M     90   (85, 90]

# %%
df['score'].nsmallest(3)
# Out:
# 4    70
# 2    75
# 6    75
# Name: score, dtype: int64

# %%
df.nsmallest(3,'score')
# Out:
#    age gender  score score_bins
# 4   45      M     70   (60, 70]
# 2   18      F     75   (70, 80]
# 6   35      M     75   (70, 80]

# %%
#4. query
df
# Out:
#    age gender  score score_bins
# 0   25      M     90   (85, 90]
# 1   22      F     80   (70, 80]
# 2   18      F     75   (70, 80]
# 3   30      M     95  (90, 100]
# 4   45      M     70   (60, 70]
# 5   50      F     85   (80, 85]
# 6   35      M     75   (70, 80]
# 7   20      F     90   (85, 90]
# 8   55      M     95  (90, 100]
# 9   40      M     85   (80, 85]

# %%
df.query('age>25 and gender=="F"')
# Out:
#    age gender  score score_bins
# 5   50      F     85   (80, 85]

# %%
#String Functions from here

# %%
dict1 = {'Name': ['Priyang Bhatt', 'Rashmin Panchal', 'Anil Rana', 'Rahul Patel'],
        'City': [' New York ', ' Los Angeles ', ' Chicago', ' Houston'],
        'State': ['NY', 'CA', 'IL', 'TX']}
data1 = pd.DataFrame(dict1)
data1
# Out:
#               Name           City State
# 0    Priyang Bhatt      New York     NY
# 1  Rashmin Panchal   Los Angeles     CA
# 2        Anil Rana        Chicago    IL
# 3      Rahul Patel        Houston    TX

# %%
#5. str.strip()
data1['City'][0]
# Out:
# ' New York '

# %%
data1['City_strip']=data1['City'].str.strip()

# %%
data1['City_strip'][0]
# Out:
# 'New York'

# %%
data1['City'][0]
# Out:
# ' New York '

# %%
data1['city_lstrip']=data1['City'].str.lstrip()

# %%
data1['city_lstrip'][0]
# Out:
# 'New York '

# %%
data1['city_rstrip']=data1['City'].str.rstrip()

# %%
data1['city_rstrip'][0]
# Out:
# ' New York'
